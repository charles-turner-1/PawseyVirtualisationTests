# %%
import xarray as xr
import icechunk
from dotenv import load_dotenv
import os
url = "s3://ct-icechunk-root/cj877-atm-icechunk"

load_dotenv()

access_key_id = os.environ.get("CJ877_ACCESS_KEY_ID")
secret_access_key = os.environ.get("CJ877_SECRET_ACCESS_KEY")

storage = icechunk.s3_storage(
    endpoint_url="https://cloud.nci.org.au:8080",
    bucket="ct-icechunk-root",
    prefix="cj877-atm-icechunk",
    force_path_style=True,
    # access_key_id = access_key_id,
    # secret_access_key =secret_access_key,
    anonymous=True,
)

credentials = icechunk.containers_credentials({
    'file:///g/data/p73/archive/non-CMIP/ACCESS-CM2/cj877/': None,
})


repo = icechunk.Repository.open(storage, authorize_virtual_chunk_access=credentials)


session = repo.readonly_session("main")

xr.open_zarr(session.store, consolidated=False, decode_times=False, decode_cf=False, decode_coords=False, decode_timedelta=False)
# Out:
#   2026-03-26T08:55:23.679839Z  WARN aws_config::imds::region: failed to load region from IMDS, err: failed to load IMDS session token: dispatch failure: timeout: error trying to connect: HTTP connect timeout occurred after 1s: HTTP connect timeout occurred after 1s: timed out (FailedToLoadToken(FailedToLoadToken { source: DispatchFailure(DispatchFailure { source: ConnectorError { kind: Timeout, source: hyper::Error(Connect, HttpTimeoutError { kind: "HTTP connect", duration: 1s }), connection: Unknown } }) }))
#     at /Users/runner/miniforge3/conda-bld/icechunk_1759410287026/_build_env/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/aws-config-1.5.18/src/imds/region.rs:66
# ---------------------------------------------------------------------------
# IcechunkError                             Traceback (most recent call last)
# Cell In[2], line 27
#      12 storage = icechunk.s3_storage(
#      13     endpoint_url="https://cloud.nci.org.au:8080",
#      14     bucket="ct-icechunk-root",
#    (...)     19     anonymous=True,
#      20 )
#      22 credentials = icechunk.containers_credentials({
#      23     'file:///g/data/p73/archive/non-CMIP/ACCESS-CM2/cj877/': None,
#      24 })
# ---> 27 repo = icechunk.Repository.open(storage, authorize_virtual_chunk_access=credentials)
#      30 session = repo.readonly_session("main")
#      32 xr.open_zarr(session.store, consolidated=False, decode_times=False, decode_cf=False, decode_coords=False, decode_timedelta=False)
#
# File ~/miniforge3/lib/python3.12/site-packages/icechunk/repository.py:149, in Repository.open(cls, storage, config, authorize_virtual_chunk_access)
#     112 @classmethod
#     113 def open(
#     114     cls,
#    (...)    117     authorize_virtual_chunk_access: dict[str, AnyCredential | None] | None = None,
#     118 ) -> Self:
#     119     """
#     120     Open an existing Icechunk repository.
#     121
#    (...)    146         An instance of the Repository class.
#     147     """
#     148     return cls(
# --> 149         PyRepository.open(
#     150             storage,
#     151             config=config,
#     152             authorize_virtual_chunk_access=authorize_virtual_chunk_access,
#     153         )
#     154     )
#
# IcechunkError:   x error getting object from object store service error
#   |
#   | context:
#   |    0: icechunk::storage::s3::get_ref
#   |            with ref_key="branch.main/ref.json"
#   |              at icechunk/src/storage/s3.rs:754
#   |    1: icechunk::refs::fetch_branch
#   |            with name="main"
#   |              at icechunk/src/refs.rs:381
#   |    2: icechunk::refs::fetch_branch_tip
#   |            with name="main"
#   |              at icechunk/src/refs.rs:400
#   |    3: icechunk::repository::exists
#   |              at icechunk/src/repository.rs:343
#   |    4: icechunk::repository::open
#   |              at icechunk/src/repository.rs:250
#   |
#   |-> error getting object from object store service error
#   |-> service error
#   |-> unhandled error (NoSuchBucket)
#   `-> Error { code: "NoSuchBucket", message: "", aws_request_id: "tx00000b12ee0ccb498638b-0069c4f47c-a98a71c-nci-dc" }

# %%
url = "https://cloud.nci.org.au:8080/swift/v1/AUTH_de20573c22894dda9a98b247bd936171/ct-icechunk-root/cj877-atm.json"
ds = xr.open_dataset(
    "reference://", engine="zarr",
    backend_kwargs={
        "storage_options": {
            "fo": url,
        },
        "consolidated": False
    }, 
decode_times=False, decode_cf=False, decode_coords=False, decode_timedelta=False,
chunks="auto"

)
ds
# Out:
# <xarray.Dataset> Size: 59GB
# Dimensions:             (time: 15218, lat: 144, lon: 192, bnds: 2, depth: 6)
# Coordinates:
#   * time                (time) float64 122kB 0.5 1.5 2.5 ... 1.522e+04 1.522e+04
#   * lat                 (lat) float64 1kB -89.38 -88.12 -86.88 ... 88.12 89.38
#   * lon                 (lon) float64 2kB 0.9375 2.812 4.688 ... 357.2 359.1
#   * depth               (depth) float64 48B 0.011 0.051 0.157 0.4385 1.185 3.164
# Dimensions without coordinates: bnds
# Data variables: (12/27)
#     fld_s01i201         (time, lat, lon) float32 2GB dask.array<chunksize=(1213, 144, 192), meta=np.ndarray>
#     latitude_longitude  (time) int32 61kB dask.array<chunksize=(15218,), meta=np.ndarray>
#     time_bnds           (time, bnds) float64 243kB dask.array<chunksize=(15218, 2), meta=np.ndarray>
#     lat_bnds            (time, lat, bnds) float64 35MB dask.array<chunksize=(15218, 144, 2), meta=np.ndarray>
#     lon_bnds            (time, lon, bnds) float64 47MB dask.array<chunksize=(15218, 192, 2), meta=np.ndarray>
#     fld_s02i201         (time, lat, lon) float32 2GB dask.array<chunksize=(1213, 144, 192), meta=np.ndarray>
#     ...                  ...
#     depth_bnds          (time, depth, bnds) float64 1MB dask.array<chunksize=(15218, 6, 2), meta=np.ndarray>
#     fld_s08i229         (time, depth, lat, lon) float32 10GB dask.array<chunksize=(202, 6, 144, 192), meta=np.ndarray>
#     fld_s08i230         (time, depth, lat, lon) float32 10GB dask.array<chunksize=(202, 6, 144, 192), meta=np.ndarray>
#     fld_s16i222         (time, lat, lon) float32 2GB dask.array<chunksize=(1213, 144, 192), meta=np.ndarray>
#     height              float64 8B ...
#     height_0            float64 8B ...
# Attributes:
#     history:      File /jobfs/32039470.gadi-pbs/cj877a.pd0001jan converted wi...
#     Conventions:  CF-1.6
#     source:       Data from Met Office Unified Model
#     um_version:   10.6

# %%
import xarray as xr
import icechunk
from dotenv import load_dotenv
import os
url = "s3://ct-icechunk-root/cj877-atm-icechunk"

load_dotenv()

access_key_id = os.environ.get("CJ877_ACCESS_KEY_ID")
secret_access_key = os.environ.get("CJ877_SECRET_ACCESS_KEY")

storage = icechunk.s3_storage(
    endpoint_url="https://cloud.nci.org.au:8080",
    bucket="ct-icechunk-root",
    prefix="cj877-atm-icechunk",
    force_path_style=True,
    access_key_id = access_key_id,
    secret_access_key =secret_access_key,
    # anonymous=True,
)

credentials = icechunk.containers_credentials({
    'file:///g/data/p73/archive/non-CMIP/ACCESS-CM2/cj877/': None,
})


repo = icechunk.Repository.open(storage, authorize_virtual_chunk_access=credentials)


session = repo.readonly_session("main")

xr.open_zarr(session.store, consolidated=False, decode_times=False, decode_cf=False, decode_coords=False, decode_timedelta=False)
# Out:
#   2026-03-26T23:26:57.307273Z  WARN aws_config::imds::region: failed to load region from IMDS, err: failed to load IMDS session token: dispatch failure: timeout: error trying to connect: HTTP connect timeout occurred after 1s: HTTP connect timeout occurred after 1s: timed out (FailedToLoadToken(FailedToLoadToken { source: DispatchFailure(DispatchFailure { source: ConnectorError { kind: Timeout, source: hyper::Error(Connect, HttpTimeoutError { kind: "HTTP connect", duration: 1s }), connection: Unknown } }) }))
#     at /Users/runner/miniforge3/conda-bld/icechunk_1759410287026/_build_env/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/aws-config-1.5.18/src/imds/region.rs:66
# /Users/u1166368/miniforge3/lib/python3.12/site-packages/zarr/codecs/numcodecs/_codecs.py:141: ZarrUserWarning: Numcodecs codecs are not in the Zarr version 3 specification and may not be supported by other zarr implementations.
#   super().__init__(**codec_config)
# <xarray.Dataset> Size: 59GB
# Dimensions:             (time: 15218, lat: 144, lon: 192, depth: 6, bnds: 2)
# Coordinates:
#   * depth               (depth) float64 48B 0.011 0.051 0.157 0.4385 1.185 3.164
#   * time                (time) float64 122kB 0.5 1.5 2.5 ... 1.522e+04 1.522e+04
#   * lon                 (lon) float64 2kB 0.9375 2.812 4.688 ... 357.2 359.1
#   * lat                 (lat) float64 1kB -89.38 -88.12 -86.88 ... 88.12 89.38
# Dimensions without coordinates: bnds
# Data variables: (12/27)
#     fld_s03i234         (time, lat, lon) float32 2GB dask.array<chunksize=(1, 144, 192), meta=np.ndarray>
#     fld_s01i201         (time, lat, lon) float32 2GB dask.array<chunksize=(1, 144, 192), meta=np.ndarray>
#     depth_bnds          (time, depth, bnds) float64 1MB dask.array<chunksize=(1, 6, 2), meta=np.ndarray>
#     fld_s02i208         (time, lat, lon) float32 2GB dask.array<chunksize=(1, 144, 192), meta=np.ndarray>
#     fld_s02i206         (time, lat, lon) float32 2GB dask.array<chunksize=(1, 144, 192), meta=np.ndarray>
#     fld_s02i201         (time, lat, lon) float32 2GB dask.array<chunksize=(1, 144, 192), meta=np.ndarray>
#     ...                  ...
#     fld_s08i230         (time, depth, lat, lon) float32 10GB dask.array<chunksize=(1, 6, 144, 192), meta=np.ndarray>
#     lon_bnds            (time, lon, bnds) float64 47MB dask.array<chunksize=(1, 192, 2), meta=np.ndarray>
#     height_0            float64 8B ...
#     latitude_longitude  (time) int32 61kB dask.array<chunksize=(1,), meta=np.ndarray>
#     lat_bnds            (time, lat, bnds) float64 35MB dask.array<chunksize=(1, 144, 2), meta=np.ndarray>
#     time_bnds           (time, bnds) float64 243kB dask.array<chunksize=(1, 2), meta=np.ndarray>
# Attributes:
#     history:      File /jobfs/32039470.gadi-pbs/cj877a.pd0001jan converted wi...
#     Conventions:  CF-1.6
#     source:       Data from Met Office Unified Model
#     um_version:   10.6
#     coordinates:  time lat lon depth height height_0
